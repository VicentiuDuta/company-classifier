# %%
# Importă bibliotecile necesare
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.style.use('ggplot')
sns.set(font_scale=1.2)

# Load classified data
df = pd.read_csv('../results/classified_companies_final.csv')

# Afișează informații generale despre dataset
print(f"Total number companies: {len(df)}")
print(f"Number of columns: {df.shape[1]}")
print(f"Available columns: {df.columns.tolist()}")

# pandas view options
pd.set_option('display.max_colwidth', None)  # Afișează tot conținutul celulelor
pd.set_option('display.width', 1000)  # Mărește lățimea de afișare

# View first 30 rows
df.head(30)
# Out:
# Total companii: 9494
# Număr de coloane: 11
# Coloane disponibile: ['description', 'business_tags', 'sector', 'category', 'niche', 'description_processed', 'business_tags_processed', 'business_tags_list', 'insurance_label', 'similarity_scores', 'classification_method']
# ...
