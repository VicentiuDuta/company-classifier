# %%
# Importă bibliotecile necesare
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setează stilul vizualizărilor - folosește un stil valid pentru matplotlib
plt.style.use('ggplot')  # sau poți folosi: 'fivethirtyeight', 'bmh', 'classic', etc.
sns.set(font_scale=1.2)

# Încarcă datele clasificate
df = pd.read_csv('../results/classified_companies.csv')

# Afișează informații generale despre dataset
print(f"Total companii: {len(df)}")
print(f"Număr de coloane: {df.shape[1]}")
print(f"Coloane disponibile: {df.columns.tolist()}")

# Afișează primele 10 rânduri pentru a vedea structura datelor
df.head(30)
# Out:
# Total companii: 9494
# Număr de coloane: 10
# Coloane disponibile: ['description', 'business_tags', 'sector', 'category', 'niche', 'description_processed', 'business_tags_processed', 'business_tags_list', 'insurance_label', 'similarity_scores']
#                                           description  \
# 0   Welchcivils is a civil engineering and constru...
# 1   Kyoto Vegetable Specialists Uekamo, also known...
# 2   Loidholdhof Integrative Hofgemeinschaft is a c...
# 3   PATAGONIA Chapa Y Pintura is an auto body shop...
# 4   Stanica WODNA PTTK Swornegacie is a cultural e...
# 5   BIQ Benefícios is a Brazilian company that spe...
# 6   EnvCompli is a company that provides personali...
# 7   Corrugated Beam Form Ltd is a company based in...
# 8   The company specializes in the production and ...
# 9   Indira Caterz And Event Managerzz is a company...
# 10  Halle Heat Exchange Equipment Co., Ltd is a Ch...
# 11  Ballymacarbry Elders Housing Association Ltd. ...
# ...
